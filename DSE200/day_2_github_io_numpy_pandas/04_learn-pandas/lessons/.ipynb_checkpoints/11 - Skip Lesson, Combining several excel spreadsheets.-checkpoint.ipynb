# %% [markdown]
# # Lesson 11
#
# Grab data from multiple excel files and merge them into a single dataframe.

# %%
import pandas as pd
import os
import sys
# %matplotlib inline

# %%
print 'Python version ' + sys.version
print 'Pandas version: ' + pd.__version__
# Out:
# Python version 2.7.10 |Anaconda 2.3.0 (64-bit)| (default, May 28 2015, 17:02:03)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# Pandas version: 0.16.2

# %% [markdown]
# # Create 3 excel files

# %%
# Create DataFrame
d = {'Channel':[1], 'Number':[255]}
df = pd.DataFrame(d)
df
# Out:
#    Channel  Number
# 0        1     255

# %%
# Export to Excel

df.to_excel('test1.xlsx', sheet_name = 'test1', index = False)
df.to_excel('test2.xlsx', sheet_name = 'test2', index = False)
df.to_excel('test3.xlsx', sheet_name = 'test3', index = False)
print 'Done'
# Out:
# Done

# %% [markdown]
# # Place all three Excel files into a DataFrame

# %% [markdown]
# Get a list of file names but make sure there are no other excel files present in the folder.

# %%
# List to hold file names
FileNames = []

# Your path will be different, please modify the path below.
#os.chdir(r"C:\Users\david\notebooks\pandas")

# Find any file that ends with ".xlsx"
for files in os.listdir("."):
    if files.endswith(".xlsx"):
        FileNames.append(files)
        
FileNames
# Out:
# ['Lesson3.xlsx', 'Lesson10.xlsx', 'test1.xlsx', 'test3.xlsx', 'test2.xlsx']

# %% [markdown]
# Create a function to process all of the excel files.

# %%
def GetFile(fnombre):

    # Path to excel file
    # Your path will be different, please modify the path below.
    location = fnombre
    
    # Parse the excel file
    # 0 = first sheet
    df = pd.read_excel(location, 0)
    
    # Tag record to file name
    df['File'] = fnombre
    
    # Make the "File" column the index of the df
    return df.set_index(['File'])

# %% [markdown]
# Go through each file name, create a dataframe, and add it to a list.
#
# i.e.
# df_list = [df, df, df]

# %%
# Create a list of dataframes
df_list = [GetFile(fname) for fname in FileNames]
df_list
# Out:
# [             State  Status  CustomerCount StatusDate
#  File
#  Lesson3.xlsx    GA       1            877 2009-01-05
#  Lesson3.xlsx    FL       1            901 2009-01-12
#  Lesson3.xlsx    fl       3            749 2009-01-19
#  Lesson3.xlsx    FL       3            111 2009-01-26
#  Lesson3.xlsx    GA       1            300 2009-02-02
#  Lesson3.xlsx    FL       2            706 2009-02-09
#  Lesson3.xlsx    TX       3            347 2009-02-16
#  Lesson3.xlsx    fl       2            143 2009-02-23
#  Lesson3.xlsx    FL       3            833 2009-03-02
#  Lesson3.xlsx    NY       1            992 2009-03-09
#  Lesson3.xlsx    fl       2            978 2009-03-16
#  Lesson3.xlsx    TX       2             32 2009-03-23
#  Lesson3.xlsx    GA       2            293 2009-03-30
#  Lesson3.xlsx    fl       1            291 2009-04-06
#  Lesson3.xlsx    fl       3            474 2009-04-13
#  Lesson3.xlsx    NJ       2            905 2009-04-20
#  Lesson3.xlsx    NJ       1            753 2009-04-27
#  Lesson3.xlsx    GA       3            309 2009-05-04
#  Lesson3.xlsx    fl       2            295 2009-05-11
#  Lesson3.xlsx    NY       3            443 2009-05-18
#  Lesson3.xlsx    TX       1             46 2009-05-25
#  Lesson3.xlsx    GA       3            591 2009-06-01
#  Lesson3.xlsx    FL       2            737 2009-06-08
#  Lesson3.xlsx    NJ       3             62 2009-06-15
#  Lesson3.xlsx    GA       3            997 2009-06-22
#  Lesson3.xlsx    GA       3            767 2009-06-29
#  Lesson3.xlsx    fl       1            723 2009-07-06
#  Lesson3.xlsx    fl       2            293 2009-07-13
#  Lesson3.xlsx    FL       1            710 2009-07-20
#  Lesson3.xlsx    NJ       1            990 2009-07-27
#  ...            ...     ...            ...        ...
#  Lesson3.xlsx    FL       3            100 2012-06-11
#  Lesson3.xlsx    fl       1            669 2012-06-18
#  Lesson3.xlsx    fl       2            348 2012-06-25
#  Lesson3.xlsx    fl       3            336 2012-07-02
#  Lesson3.xlsx    NJ       3            393 2012-07-09
#  Lesson3.xlsx    FL       3            210 2012-07-16
#  Lesson3.xlsx    FL       3            363 2012-07-23
#  Lesson3.xlsx    fl       3            995 2012-07-30
#  Lesson3.xlsx    TX       1            178 2012-08-06
#  Lesson3.xlsx    NJ       3             26 2012-08-13
#  Lesson3.xlsx    TX       1            248 2012-08-20
#  Lesson3.xlsx    NY       2             74 2012-08-27
#  Lesson3.xlsx    FL       3             46 2012-09-03
#  Lesson3.xlsx    fl       3            920 2012-09-10
#  Lesson3.xlsx    NJ       2            623 2012-09-17
#  Lesson3.xlsx    TX       3            784 2012-09-24
#  Lesson3.xlsx    fl       3            924 2012-10-01
#  Lesson3.xlsx    fl       1            716 2012-10-08
#  Lesson3.xlsx    fl       3            428 2012-10-15
#  Lesson3.xlsx    NJ       1            955 2012-10-22
#  Lesson3.xlsx    GA       2            380 2012-10-29
#  Lesson3.xlsx    fl       2            105 2012-11-05
#  Lesson3.xlsx    NJ       3            772 2012-11-12
#  Lesson3.xlsx    FL       2            390 2012-11-19
#  Lesson3.xlsx    FL       3            513 2012-11-26
#  Lesson3.xlsx    NY       2            122 2012-12-03
#  Lesson3.xlsx    TX       2            887 2012-12-10
#  Lesson3.xlsx    TX       2            988 2012-12-17
#  Lesson3.xlsx    GA       3            946 2012-12-24
#  Lesson3.xlsx    FL       2            970 2012-12-31
#
#  [836 rows x 4 columns],                Number
#  File
#  Lesson10.xlsx       1
#  Lesson10.xlsx       2
#  Lesson10.xlsx       3
#  Lesson10.xlsx       4
#  Lesson10.xlsx       5
#  Lesson10.xlsx       6
#  Lesson10.xlsx       7
#  Lesson10.xlsx       8
#  Lesson10.xlsx       9,             Channel  Number
#  File
#  test1.xlsx        1     255,             Channel  Number
#  File
#  test3.xlsx        1     255,             Channel  Number
#  File
#  test2.xlsx        1     255]

# %%
# Combine all of the dataframes into one
big_df = pd.concat(df_list)
big_df
# Out:
#                Channel  CustomerCount  Number State  Status StatusDate
# File
# Lesson3.xlsx       NaN            877     NaN    GA       1 2009-01-05
# Lesson3.xlsx       NaN            901     NaN    FL       1 2009-01-12
# Lesson3.xlsx       NaN            749     NaN    fl       3 2009-01-19
# Lesson3.xlsx       NaN            111     NaN    FL       3 2009-01-26
# Lesson3.xlsx       NaN            300     NaN    GA       1 2009-02-02
# Lesson3.xlsx       NaN            706     NaN    FL       2 2009-02-09
# Lesson3.xlsx       NaN            347     NaN    TX       3 2009-02-16
# Lesson3.xlsx       NaN            143     NaN    fl       2 2009-02-23
# Lesson3.xlsx       NaN            833     NaN    FL       3 2009-03-02
# Lesson3.xlsx       NaN            992     NaN    NY       1 2009-03-09
# Lesson3.xlsx       NaN            978     NaN    fl       2 2009-03-16
# Lesson3.xlsx       NaN             32     NaN    TX       2 2009-03-23
# Lesson3.xlsx       NaN            293     NaN    GA       2 2009-03-30
# Lesson3.xlsx       NaN            291     NaN    fl       1 2009-04-06
# Lesson3.xlsx       NaN            474     NaN    fl       3 2009-04-13
# Lesson3.xlsx       NaN            905     NaN    NJ       2 2009-04-20
# Lesson3.xlsx       NaN            753     NaN    NJ       1 2009-04-27
# Lesson3.xlsx       NaN            309     NaN    GA       3 2009-05-04
# Lesson3.xlsx       NaN            295     NaN    fl       2 2009-05-11
# Lesson3.xlsx       NaN            443     NaN    NY       3 2009-05-18
# Lesson3.xlsx       NaN             46     NaN    TX       1 2009-05-25
# Lesson3.xlsx       NaN            591     NaN    GA       3 2009-06-01
# Lesson3.xlsx       NaN            737     NaN    FL       2 2009-06-08
# Lesson3.xlsx       NaN             62     NaN    NJ       3 2009-06-15
# Lesson3.xlsx       NaN            997     NaN    GA       3 2009-06-22
# Lesson3.xlsx       NaN            767     NaN    GA       3 2009-06-29
# Lesson3.xlsx       NaN            723     NaN    fl       1 2009-07-06
# Lesson3.xlsx       NaN            293     NaN    fl       2 2009-07-13
# Lesson3.xlsx       NaN            710     NaN    FL       1 2009-07-20
# Lesson3.xlsx       NaN            990     NaN    NJ       1 2009-07-27
# ...                ...            ...     ...   ...     ...        ...
# Lesson3.xlsx       NaN             46     NaN    FL       3 2012-09-03
# Lesson3.xlsx       NaN            920     NaN    fl       3 2012-09-10
# Lesson3.xlsx       NaN            623     NaN    NJ       2 2012-09-17
# Lesson3.xlsx       NaN            784     NaN    TX       3 2012-09-24
# Lesson3.xlsx       NaN            924     NaN    fl       3 2012-10-01
# Lesson3.xlsx       NaN            716     NaN    fl       1 2012-10-08
# Lesson3.xlsx       NaN            428     NaN    fl       3 2012-10-15
# Lesson3.xlsx       NaN            955     NaN    NJ       1 2012-10-22
# Lesson3.xlsx       NaN            380     NaN    GA       2 2012-10-29
# Lesson3.xlsx       NaN            105     NaN    fl       2 2012-11-05
# Lesson3.xlsx       NaN            772     NaN    NJ       3 2012-11-12
# Lesson3.xlsx       NaN            390     NaN    FL       2 2012-11-19
# Lesson3.xlsx       NaN            513     NaN    FL       3 2012-11-26
# Lesson3.xlsx       NaN            122     NaN    NY       2 2012-12-03
# Lesson3.xlsx       NaN            887     NaN    TX       2 2012-12-10
# Lesson3.xlsx       NaN            988     NaN    TX       2 2012-12-17
# Lesson3.xlsx       NaN            946     NaN    GA       3 2012-12-24
# Lesson3.xlsx       NaN            970     NaN    FL       2 2012-12-31
# Lesson10.xlsx      NaN            NaN       1   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       2   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       3   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       4   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       5   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       6   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       7   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       8   NaN     NaN        NaT
# Lesson10.xlsx      NaN            NaN       9   NaN     NaN        NaT
# test1.xlsx           1            NaN     255   NaN     NaN        NaT
# test3.xlsx           1            NaN     255   NaN     NaN        NaT
# test2.xlsx           1            NaN     255   NaN     NaN        NaT
#
# [848 rows x 6 columns]

# %%
big_df.dtypes
# Out:
# Channel                 float64
# CustomerCount           float64
# Number                  float64
# State                    object
# Status                  float64
# StatusDate       datetime64[ns]
# dtype: object

# %%
# Plot it!
big_df['Channel'].plot(kind='bar');

# %% [markdown]
# **Author:** [David Rojas](http://www.hedaro.com/)
